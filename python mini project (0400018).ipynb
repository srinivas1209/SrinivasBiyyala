# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('IPL Matches 2008-2020.csv')
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#           id           city        date   player_of_match  \
# 40    336022          Delhi  2008-05-17  DPMD Jayawardene
# 43    336025        Kolkata  2008-05-18           M Ntini
# 60    392183      Cape Town  2009-04-19        DL Vettori
# 63    392186         Durban  2009-04-21          CH Gayle
# 89    392214      Centurion  2009-05-07         ML Hayden
# 192   501215          Kochi  2011-04-18       BB McCullum
# 221   501245        Kolkata  2011-05-07     Iqbal Abdulla
# 231   501255      Bangalore  2011-05-14          CH Gayle
# 429   733993          Delhi  2014-05-10          DW Steyn
# 477   829743  Visakhapatnam  2015-04-22         DA Warner
# 508   829807      Hyderabad  2015-05-15           V Kohli
# 538   980943      Hyderabad  2016-04-26          AB Dinda
# 561   980989        Kolkata  2016-05-14         YK Pathan
# 565   980997  Visakhapatnam  2016-05-17          AB Dinda
# 566   980999      Bangalore  2016-05-18           V Kohli
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df['player_of_match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: player_of_match, Length: 233, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.bar(list(df['player_of_match'].value_counts()[0:5].keys()),list(df['player_of_match'].value_counts()[0:5]),color='Blue')
plt.show()

# %%
#number of toss wins with respect to each team
x=df['toss_winner'].value_counts()
x
# Out:
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Delhi Capitals                  20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: toss_winner, dtype: int64

# %%
plt.pie(x,labels=x.index, autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22e34900850>,
# ...
#  [Text(1.0096645941578628, 0.43655172351513905, 'Mumbai Indians'),
#   Text(0.40525199721675853, 1.0226293652892178, 'Kolkata Knight Riders'),
#   Text(-0.4013118779359024, 1.0241820036631963, 'Chennai Super Kings'),
#   Text(-0.9711097578173662, 0.5166680155301822, 'Royal Challengers Bangalore'),
#   Text(-1.0820405806856397, -0.19796005089281032, 'Rajasthan Royals'),
#   Text(-0.7316269521248274, -0.821414635202305, 'Kings XI Punjab'),
#   Text(-0.10149526628984742, -1.0953075873565166, 'Delhi Daredevils'),
#   Text(0.46360024306058406, -0.9975343676456304, 'Sunrisers Hyderabad'),
#   Text(0.8042964494032612, -0.7504047051273782, 'Deccan Chargers'),
#   Text(0.9609845989417956, -0.5352649816648539, 'Pune Warriors'),
#   Text(1.0317169821753809, -0.38152335274649307, 'Delhi Capitals'),
#   Text(1.0736191714167356, -0.23946163527054262, 'Gujarat Lions'),
#   Text(1.0905893406497515, -0.14357886355985747, 'Kochi Tuskers Kerala'),
# ...

# %%
top_ten_winnings_teams =_team=df.groupby("winner")["winner"].agg(["count"]).reset_index().sort_values(by="count",ascending=False).head(10)
top_ten_winnings_teams
# Out:
#                          winner  count
# 8                Mumbai Indians    120
# 0           Chennai Super Kings    106
# 7         Kolkata Knight Riders     99
# 13  Royal Challengers Bangalore     91
# 5               Kings XI Punjab     88
# 10             Rajasthan Royals     81
# 3              Delhi Daredevils     67
# 14          Sunrisers Hyderabad     66
# 1               Deccan Chargers     29
# 2                Delhi Capitals     19

# %%
plt.figure(figsize=(8,3))
df3=sns.barplot(x='winner',y='count',data=top_ten_winnings_teams)
df3.set_title('Top 10 winnings team ')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,3))
df4=sns.countplot(x='toss_decision',data=df)
df4.set_title('COMPARISION BATTING OR FIELDING ')
plt.xticks(rotation=90)
plt.show()

# %%
toss_winner=df.groupby("toss_winner")["toss_winner"].agg(["count"]).reset_index().sort_values(by="count",ascending=False).head(10)
toss_winner
# Out:
#                     toss_winner  count
# 8                Mumbai Indians    106
# 7         Kolkata Knight Riders     98
# 0           Chennai Super Kings     97
# 10             Rajasthan Royals     87
# 13  Royal Challengers Bangalore     87
# 5               Kings XI Punjab     85
# 3              Delhi Daredevils     80
# 14          Sunrisers Hyderabad     57
# 1               Deccan Chargers     43
# 2                Delhi Capitals     20

# %%
plt.figure(figsize=(8,3))
df5=sns.barplot(x='toss_winner',y='count',data=toss_winner)
df5.set_title('MOST TOSS WINNER')
plt.xticks(rotation=90)
plt.show()

# %%
most_mom_df = pd.DataFrame(data = df["player_of_match"].value_counts().iloc[:15])
most_mom_df = most_mom_df
most_mom_df
# Out:
#                 player_of_match
# AB de Villiers               23
# CH Gayle                     22
# RG Sharma                    18
# DA Warner                    17
# MS Dhoni                     17
# SR Watson                    16
# YK Pathan                    16
# SK Raina                     14
# V Kohli                      13
# G Gambhir                    13
# AM Rahane                    12
# MEK Hussey                   12
# AD Russell                   11
# A Mishra                     11
# KA Pollard                   11

# %%
plt.figure(figsize = (12,6))
sns.countplot(y = 'player_of_match',
              data = df,
              order = df['player_of_match'].value_counts().iloc[:10].index,
              palette='rainbow')
plt.xlabel('No: of matches',fontsize=12)
plt.ylabel('Player Name',fontsize=12)
plt.title('Most man of Match',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Most man of Match')

# %%
plt.figure(figsize = (12,18))
sns.countplot(y = 'venue',
              data = df,
              order = df['venue'].value_counts().iloc[:20].index,
              palette='gist_heat')
plt.xlabel('No: of matches',fontsize=12)
plt.ylabel('Venue',fontsize=12)
plt.title('Number of matches played in each Stadium',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Number of matches played in each Stadium')

# %%
plt.figure(figsize=(15,7))
sns.countplot(y='venue',
              hue='toss_decision',
              data=df,
              order = df['venue'].value_counts().iloc[:10].index.sort_values(),
              palette='deep')
plt.ylabel('venue',fontsize=12)
plt.xlabel('Count',fontsize=12)
plt.title('Decision to field or bat in each venue', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Decision to field or bat in each venue')

# %%
plt.figure(figsize = (12,12))
sns.countplot(x = 'city',
              data = df,
              order = df['city'].value_counts().iloc[:10].index,
              palette='turbo')
plt.ylabel('No: of matches',fontsize=12)
plt.xlabel('City',fontsize=12)
plt.title('Number of matches played in each City',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Number of matches played in each City')

# %%
df['year'] = [x[:4] for x in df['date']]
years = df.year.unique()
print(years)
man_of_match = pd.DataFrame([],columns=['Year','Man of Match','Times'])
for id, year in enumerate(years):
    player_of_match = df['player_of_match'][df['year']==year]
    man_of_match.loc[id] = [year, player_of_match.value_counts().index[0], player_of_match.value_counts()[0]]
man_of_match
# Out:
# ['2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017'
#  '2018' '2019' '2020']
#     Year     Man of Match  Times
# 0   2008         SE Marsh      5
# 1   2009        YK Pathan      3
# 2   2010     SR Tendulkar      4
# 3   2011         CH Gayle      6
# 4   2012         CH Gayle      5
# 5   2013       MEK Hussey      5
# 6   2014       GJ Maxwell      4
# 7   2015        DA Warner      4
# 8   2016          V Kohli      5
# 9   2017  NM Coulter-Nile      3
# 10  2018      Rashid Khan      4
# 11  2019       AD Russell      4
# 12  2020         TA Boult      3

# %%
sns.barplot(x='Man of Match',y = 'Times', data= man_of_match)
plt.xticks(rotation=90)
plt.title('Most Man of Match Year-Wise (2008-2020)')
# Out:
# Text(0.5, 1.0, 'Most Man of Match Year-Wise (2008-2020)')
